# %%
import requests
import datetime

res = requests.get('https://airoco.necolico.jp/data-api/latest?id=CgETViZ2&subscription-key=6b8aa7133ece423c836c38af01c59880')
# print(res.status_code)
# print(res.text)
for i in range(9):
  res_json = res.json()[i]
  # print(res_json)
  sensorNumber = res_json['sensorNumber']
  sensorName = res_json['sensorName']
  print(sensorNumber, sensorName)
  co2 = res_json['co2']
  if co2==None: continue # データ無ければ次
  temperature = res_json['temperature']
  relativeHumidity = res_json['relativeHumidity']
  timestamp = res_json['timestamp']
  dt = datetime.datetime.fromtimestamp(timestamp)
  print(f'CO2濃度={co2}[ppm], 気温={temperature}[deg], 相対湿度={relativeHumidity}[%], タイムスタンプ={dt}\n');
# Out:
# 440103256242854 予備２
# 440103264789636 Ｒ３ー４０１
# CO2濃度=547.0[ppm], 気温=20.5[deg], 相対湿度=44.6[%], タイムスタンプ=2025-03-26 05:38:21
#
# 440103265321573 Ｒ３ー３０１
# CO2濃度=556.0[ppm], 気温=21.8[deg], 相対湿度=39.9[%], タイムスタンプ=2025-03-26 05:38:47
#
# 440103265767046 予備３
# 440103265317641 Ｒ３ー３Ｆ_ＥＨ
# CO2濃度=482.0[ppm], 気温=24.7[deg], 相対湿度=34.7[%], タイムスタンプ=2025-03-26 05:38:14
#
# 440103265869457 Ｒ３ー４Ｆ_ＥＨ
# CO2濃度=523.0[ppm], 気温=27.5[deg], 相対湿度=28.1[%], タイムスタンプ=2025-03-26 05:34:40
#
# 440103265370286 予備４
# 440103264788998 Ｒ３ー４０３
# CO2濃度=457.0[ppm], 気温=20.4[deg], 相対湿度=41.6[%], タイムスタンプ=2025-03-26 05:36:20
#
# 440103255555215 Ｒ３ーB１Ｆ_ＥＨ
# CO2濃度=519.0[ppm], 気温=20.8[deg], 相対湿度=47.3[%], タイムスタンプ=2025-03-26 05:33:19
